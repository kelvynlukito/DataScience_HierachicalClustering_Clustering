# %% [markdown]
# <a href="https://colab.research.google.com/github/kelvynlukito/DataScience_HierachicalClustering_Clustering/blob/main/DataScience_HierachicalClustering_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Hierarchical Clustering**

# %% [markdown]
# # **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Import Dataset**

# %%
df = pd.read_csv('/content/Mall_Customers.csv')
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
X = df.iloc[:,[3,4]].values
print(X)

# %% [markdown]
# # **Using Dendrogram to Find Optimal Clusters**

# %%
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(X, method='ward'))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean Distances')
plt.show()

# %% [markdown]
# # **Training Hierachical Clustering Model on Dataset**

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
hc_5 = AgglomerativeClustering(n_clusters=5, metric='euclidean', linkage='ward')
hc_3 = AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage='ward')

# %%
y_hc_5 = hc_5.fit_predict(X)
y_hc_3 = hc_3.fit_predict(X)

# %% [markdown]
# # **Visualising Cluster**

# %%
for i in range(len(np.unique(y_hc_5))):
  plt.scatter(X[y_hc_5==i, 0] ,X[y_hc_5 == i, 1], label=f'Cluster {i+1}')
  plt.legend()
  plt.title('HC Cluster 5')
  plt.xlabel('Customer Income')
  plt.ylabel('Spending Score')

# %%
for i in range(len(np.unique(y_hc_3))):
  plt.scatter(X[y_hc_3==i, 0] ,X[y_hc_3 == i, 1], label=f'Cluster {i+1}')
  plt.legend()
  plt.title('HC Cluster 3')
  plt.xlabel('Customer Income')
  plt.ylabel('Spending Score')
